# %% [markdown]
# ## **EDA Project on diabetes dataset**

# %% [markdown]
# #**Introduction**
#
# **In India, diabetes is a major issue. Between 1971 and 2000, the incidence of diabetes rose ten times, from 1.2% to 12.1%. 61.3 million people 20–79 years of age in India are estimated living with diabetes (Expectations of 2011). It is expected that by 2030 this number will rise to 101,2 million. In India there are reportedly 77.2 million people with prediabetes. In 2012, nearly 1 million people in India died of diabetes. 1 out of 4 individuals living in Chennai’s urban slums suffer from diabetes, which is about 7 per cent by three times the national average. One third of the deaths in India involve people under non-communicable diseases Sixty years old. Indians get diabetes 10 years before their Western counterparts on average. Changes in lifestyle lead to physical decreases Increased fat, sugar and activities activity calories and higher insulin cortisol levels Obesity and vulnerability. In 2011, India cost around $38 billion annually as a result of diabetes.**

# %% [markdown]
# #**Context**
# **This dataset comes from the Diabetes and Digestive and Kidney Disease National Institutes. The purpose of this dataset is to diagnose whether or not a patient is diabetic, on the basis of certain diagnostic measures in the dataset. The selection of these instances from a larger database was subject to several restrictions. All patients are women from the Indian heritage of Pima, at least 21 years old**

# %% [markdown]
# #**Dataset:**
# **Pima Indians Diabetes Database (Predict the onset of diabetes based on diagnostic measures)**
#
# **This data set two population , diabetic and non-diabetic. this two populations are handled separertly for better accuracy**

# %% [markdown]
# #**Aim:**
# **Aim of this Project is to compare the  biological parameters for diabetic person and on-diabetic person**
#
# **To Find the relation between different biological parameter on diabetes**
#
# **To find best parameter to detect diabetes**

# %% [markdown]
# #**Attribute Information:**
#
# **Pregnancies: Number of times pregnant**
#
# **Glucose: Plasma glucose concentration 2 hours in an oral glucose tolerance test**
#
# **Blood Pressure: Diastolic blood pressure (mm Hg)**
#
# **Skin Thickness: Triceps skin fold thickness (mm)**
#
# **Insulin: 2-Hour serum insulin (mu U/ml)**
#
# **BMI: Body mass index (weight in kg/(height in m)^2)**
#
# **Diabetes Pedigree Function: Diabetes pedigree function**
#
# **Age: Age (years)**
#
# **Outcome: Class variable (0 or 1) 0 mean non-diabetic and 1 means diabetic**

# %%
import pandas as pd # importing required librery
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
colnames=['Pregnancies', 'Glucose', 'Blood_Pressure', 'Skin_Thickness','Insulin','BMI','Diabetes_Pedigree_Function','Age','Outcome'] 

df = pd.read_excel("/content/diabetes_mandatory_EDA (2).xlsx",names=colnames, header= None)

# %% [markdown]
# ##**Basic data exploration**

# %%
df.shape # checking size of the data set
print('numer of rows are ',df.shape[0])
print('numer of rows are ',df.shape[1])
# Out:
# numer of rows are  768
# numer of rows are  9

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  Blood_Pressure  Skin_Thickness  Insulin   BMI  \
# 0          6.0    148.0            72.0            35.0      0.0  33.6
# 1          1.0     85.0            66.0            29.0      0.0  26.6
# 2          8.0    183.0            64.0             0.0      0.0  23.3
# 3          1.0     89.0            66.0            23.0     94.0  28.1
# 4          0.0    137.0            40.0            35.0    168.0  43.1
# 5          5.0    116.0            74.0             0.0      0.0  25.6
# 6          3.0     78.0            50.0            32.0     88.0  31.0
# 7         10.0    115.0             0.0             0.0      0.0  35.3
# 8          2.0    197.0            70.0            45.0    543.0  30.5
# 9          8.0    125.0            96.0             0.0      0.0   0.0
#
#    Diabetes_Pedigree_Function   Age  Outcome
# 0                       0.627  50.0      1.0
# 1                       0.351  31.0      0.0
# 2                       0.672  32.0      1.0
# ...

# %%
df.tail(10)
# Out:
#      Pregnancies  Glucose  Blood_Pressure  Skin_Thickness  Insulin   BMI  \
# 758          1.0    106.0            76.0             0.0      0.0  37.5
# 759          6.0    190.0            92.0             0.0      0.0  35.5
# 760          2.0     88.0            58.0            26.0     16.0  28.4
# 761          9.0    170.0            74.0            31.0      0.0  44.0
# 762          9.0     89.0            62.0             0.0      0.0  22.5
# 763         10.0    101.0            76.0            48.0    180.0  32.9
# 764          2.0    122.0            70.0            27.0      0.0  36.8
# 765          5.0    121.0            72.0            23.0    112.0  26.2
# 766          1.0    126.0            60.0             0.0      0.0  30.1
# 767          1.0     93.0            70.0            31.0      0.0  30.4
#
#      Diabetes_Pedigree_Function   Age  Outcome
# 758                       0.197  26.0      0.0
# 759                       0.278  66.0      1.0
# ...

# %%
df.info() # checking data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Pregnancies                 768 non-null    float64
#  1   Glucose                     768 non-null    float64
#  2   Blood_Pressure              768 non-null    float64
#  3   Skin_Thickness              768 non-null    float64
#  4   Insulin                     768 non-null    float64
#  5   BMI                         768 non-null    float64
#  6   Diabetes_Pedigree_Function  768 non-null    float64
#  7   Age                         768 non-null    float64
#  8   Outcome                     768 non-null    float64
# dtypes: float64(9)
# memory usage: 54.1 KB

# %%
df = df.astype({"Pregnancies" : int}) # changing data type to int

# %%
df= df.astype({"Outcome" : int})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Pregnancies                 768 non-null    int64
#  1   Glucose                     768 non-null    float64
#  2   Blood_Pressure              768 non-null    float64
#  3   Skin_Thickness              768 non-null    float64
#  4   Insulin                     768 non-null    float64
#  5   BMI                         768 non-null    float64
#  6   Diabetes_Pedigree_Function  768 non-null    float64
#  7   Age                         768 non-null    float64
#  8   Outcome                     768 non-null    int64
# dtypes: float64(7), int64(2)
# memory usage: 54.1 KB

# %%
df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       0
# Blood_Pressure                0
# Skin_Thickness                0
# Insulin                       0
# BMI                           0
# Diabetes_Pedigree_Function    0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
df.Pregnancies.value_counts()
# Out:
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: Pregnancies, dtype: int64

# %%
df.describe( include ="all") # checking statical data
# Out:
#        Pregnancies     Glucose  Blood_Pressure  Skin_Thickness     Insulin  \
# count   768.000000  768.000000      768.000000      768.000000  768.000000
# mean      3.845052  120.894531       69.105469       20.536458   79.799479
# std       3.369578   31.972618       19.355807       15.952218  115.244002
# min       0.000000    0.000000        0.000000        0.000000    0.000000
# 25%       1.000000   99.000000       62.000000        0.000000    0.000000
# 50%       3.000000  117.000000       72.000000       23.000000   30.500000
# 75%       6.000000  140.250000       80.000000       32.000000  127.250000
# max      17.000000  199.000000      122.000000       99.000000  846.000000
#
#               BMI  Diabetes_Pedigree_Function         Age     Outcome
# count  768.000000                  768.000000  768.000000  768.000000
# mean    31.992578                    0.471876   33.240885    0.348958
# std      7.884160                    0.331329   11.760232    0.476951
# ...

# %% [markdown]
# we can see that column Glucose, blood pressure, Skinthickness, Insulin BMI has minimun value = 0. which is practicaly not posible.

# %%
fig,axes = plt.subplots(nrows = 2, ncols = 3, figsize = (18,10)) ## Checking for ditriution
sns.histplot(x ="Glucose", data = df, kde = True,ax=axes[0,0]).set(title = "Distribution of Glucose")
sns.histplot(x ="Blood_Pressure", data = df, kde = True,ax=axes[0,1]).set(title = "Distribution of Blood_Pressure")
sns.histplot(x ="Skin_Thickness", data = df, kde = True,ax=axes[0,2]).set(title = "Distribution of Skin_Thickness")
sns.histplot(x ="Insulin", data = df, kde = True,ax=axes[1,0]).set(title = "Distribution of Insulin")
sns.histplot(x ="BMI", data = df, kde = True,ax=axes[1,1]).set(title = "Distribution of BMI")

# sns.histplot(x= "Glucose", data = df, kde = True )
# Out:
# [Text(0.5, 1.0, 'Distribution of BMI')]

# %%
print("Count of zeros in Glucose colun is " ,df.Glucose[df.Glucose==0].count())
print("Count of zeros in Blood pressure colun is " ,df.Blood_Pressure[df.Blood_Pressure==0].count())
print("Count of zeros in  Skin_Thickness colun is " ,df.Skin_Thickness[df.Skin_Thickness==0].count())
print("Count of zeros in Insulin colun is " ,df.Insulin[df.Insulin==0].count())
print("Count of zeros in BMI colun is " ,df.BMI[df.BMI==0].count())
# Out:
# Count of zeros in Glucose colun is  5
# Count of zeros in Blood pressure colun is  35
# Count of zeros in  Skin_Thickness colun is  227
# Count of zeros in Insulin colun is  374
# Count of zeros in BMI colun is  11

# %% [markdown]
# **ABOVE Figure shows the presence of zero in column, which is irrelevant.** **also we can see number of zeros on those column.**
# **most of zeros are found in column insulin. But insulin is a key factore** **of diebetic. so dropping zeros will effect the Analysis..**

# %%
df['Glucose'] = df['Glucose'].replace(0,np.NaN) # replacing with NAN
df['Blood_Pressure'] = df['Blood_Pressure'].replace(0,np.NaN)
df['Skin_Thickness'] = df['Skin_Thickness'].replace(0,np.NaN)
df['Insulin'] = df['Insulin'].replace(0,np.NaN)
df['BMI'] = df['BMI'].replace(0,np.NaN)

# %% [markdown]
# ABOVE Figure shows the presence of zero in column, which is irrelevant. also we can see number of zeros on those column.
# most of zeros are found in column insulin. But insulin is a key factore of diebetic. so dropping zeros will effect the outcome..

# %% [markdown]
# # **Let us spilt the data to diabetic and non diabetic people for further analysis**

# %%
df_d = df[df.Outcome == 1] # df_d dataset contains details of only diabetic people

# %%
df_n = df[df.Outcome == 0] #df_n dataset contains details of only non diabetic people

# %% [markdown]
# ##**Exploring data set of diabetic people df_d**

# %%
df_d.shape # size of diabetic dataframe
# Out:
# (268, 9)

# %%
df_n.shape # Size of non diabetic dataframe
# Out:
# (500, 9)

# %% [markdown]
# Checking for irrelevent value zero in the data set

# %%
df_d.describe(include = "all")
# Out:
#        Pregnancies     Glucose  Blood_Pressure  Skin_Thickness     Insulin  \
# count   268.000000  268.000000      268.000000      268.000000  268.000000
# mean      4.865672  141.257463       70.824627       22.164179  100.335821
# std       3.741239   31.939622       21.491812       17.679711  138.689125
# min       0.000000    0.000000        0.000000        0.000000    0.000000
# 25%       1.750000  119.000000       66.000000        0.000000    0.000000
# 50%       4.000000  140.000000       74.000000       27.000000    0.000000
# 75%       8.000000  167.000000       82.000000       36.000000  167.250000
# max      17.000000  199.000000      114.000000       99.000000  846.000000
#
#               BMI  Diabetes_Pedigree_Function         Age  Outcome
# count  268.000000                  268.000000  268.000000    268.0
# mean    35.142537                    0.550500   37.067164      1.0
# std      7.262967                    0.372354   10.968254      0.0
# ...

# %% [markdown]
# we can see that column Glucose, blood pressure, Skinthickness, Insulin BMI has minimun value = 0. which is practicaly not posible.

# %%
df_d.duplicated().sum() #Counting dublicates in diabetic data set
# Out:
# 0

# %%
df_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 268 entries, 0 to 766
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Pregnancies                 268 non-null    int64
#  1   Glucose                     266 non-null    float64
#  2   Blood_Pressure              252 non-null    float64
#  3   Skin_Thickness              180 non-null    float64
#  4   Insulin                     130 non-null    float64
#  5   BMI                         266 non-null    float64
#  6   Diabetes_Pedigree_Function  268 non-null    float64
#  7   Age                         268 non-null    float64
#  8   Outcome                     268 non-null    int64
# dtypes: float64(7), int64(2)
# memory usage: 20.9 KB

# %%
df_d.isnull().sum() # COunting missing values for eacch count
# Out:
# Pregnancies                     0
# Glucose                         2
# Blood_Pressure                 16
# Skin_Thickness                 88
# Insulin                       138
# BMI                             2
# Diabetes_Pedigree_Function      0
# Age                             0
# Outcome                         0
# dtype: int64

# %% [markdown]
# **we can see Triceps skin thickness and insulin has more missing values.**
#
# **But as per medicle science this two are key factore for deciding diabetis for a person, so drop this can effect the out come**
#
# **we will go for Replacing missing values**

# %%
import missingno as msno # Graphical representation of missing values
msno.bar(df_d)

# %% [markdown]
# Above graph shows that, Graphical representation of missing values.

# %%
sorted_matrix = df_d.sort_values(['Skin_Thickness','Insulin']) # matrix view of missing values
msno.matrix(sorted_matrix)
plt.show()

# %% [markdown]
# **Above Graph shows that, white line indicates that missing values**
# **We Can observe that the column skin thickness and Insulin has Relationin missing values.**

# %%
msno.heatmap(df_d) # checking for corelation

# %% [markdown]
# **Above Graph Heat Mapp shows the co realation between columns**
#
# **We can observe that skin thickness and Insulin are highly positive co realated**

# %% [markdown]
# **We are replacing null values with median and KNN. and then checking the best fit out of this**

# %%
from sklearn.impute import SimpleImputer # Using median imputation for null value
df_d_median = df_d.copy( deep = True)
median_imputer = SimpleImputer(strategy = "median")
df_d_median.iloc[:, :] = median_imputer.fit_transform(df_d_median)

# %%
df_d_median.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 268 entries, 0 to 766
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Pregnancies                 268 non-null    float64
#  1   Glucose                     268 non-null    float64
#  2   Blood_Pressure              268 non-null    float64
#  3   Skin_Thickness              268 non-null    float64
#  4   Insulin                     268 non-null    float64
#  5   BMI                         268 non-null    float64
#  6   Diabetes_Pedigree_Function  268 non-null    float64
#  7   Age                         268 non-null    float64
#  8   Outcome                     268 non-null    float64
# dtypes: float64(9)
# memory usage: 20.9 KB

# %%
pip install fancyimpute

# %%
#from fancyimpute import  # knn implimenation for missing values
from fancyimpute import KNN
knn_imputer = KNN()
df_d_knn = df_d.copy( deep = True)
df_d_knn.iloc[:, :] = knn_imputer.fit_transform(df_d_knn)
# Out:
# Imputing row 1/268 with 1 missing, elapsed time: 0.021
# Imputing row 101/268 with 2 missing, elapsed time: 0.024
# Imputing row 201/268 with 1 missing, elapsed time: 0.026

# %% [markdown]
# **Checking for best fit out of median and KNN Imputation**

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2, figsize = (10,7))
nullity = df_d['Skin_Thickness'].isnull() + df_d['Insulin'].isnull()
imputations = {'Median Imputation' : df_d_median, 
               'KNN Imputation': df_d_knn}

for ax, df_key in zip(axes.flatten(), imputations):
  imputations[df_key].plot(x ='Skin_Thickness', y = 'Insulin', kind = 'scatter', alpha = 0.5, c= nullity, cmap = 'rainbow', ax = ax,colorbar = False, title = df_key)

# %% [markdown]
# **From Abov Graph we can conclude that, for data fram df_d [Information about diabetic person] KNN Imputation wiil be the better approch.**
#
# **because in above plot we can observe that KNN imputation is almost similar to to the dataset, compared to median imputation**

# %% [markdown]
# Note: **df_d_knn** this dataframe contains knn imputed diabetic person dataset

# %%
df_d_knn.isnull().sum() # Checking missing values after imputation
# Out:
# Pregnancies                   0
# Glucose                       0
# Blood_Pressure                0
# Skin_Thickness                0
# Insulin                       0
# BMI                           0
# Diabetes_Pedigree_Function    0
# Age                           0
# Outcome                       0
# dtype: int64

# %% [markdown]
# ##**Analyzing the KNN Imputed data set for diabetic personal, that is df_d_knn**

# %% [markdown]
# ## **Checking for Outlier**

# %%
sns.boxplot(x ="Age", data = df_d_knn).set(title = "Distribution of BMI")
# Out:
# [Text(0.5, 1.0, 'Distribution of BMI')]

# %%
fig,axes = plt.subplots(nrows = 2, ncols = 3, figsize = (18,10))  # Here Box plot is used for numerical data column to check outlier in the each column
sns.boxplot(x ="Glucose", data = df_d_knn,ax=axes[0,0]).set(title = "Distribution of Glucose")
sns.boxplot(x ="Blood_Pressure", data = df_d_knn,ax=axes[0,1]).set(title = "Distribution of Blood_Pressure")
sns.boxplot(x ="Skin_Thickness", data = df_d_knn, ax=axes[0,2]).set(title = "Distribution of Skin_Thickness")
sns.boxplot(x ="Insulin", data = df_d_knn, ax=axes[1,0]).set(title = "Distribution of Insulin")
sns.boxplot(x ="BMI", data = df_d_knn, ax=axes[1,1]).set(title = "Distribution of BMI")
sns.boxplot(x="Diabetes_Pedigree_Function", data = df_d_knn)

# %%
fig,axes = plt.subplots(nrows = 2, ncols = 3, figsize = (18,10))
sns.histplot(x ="Glucose", data = df_d_knn, kde = True,ax=axes[0,0]).set(title = "Distribution of Glucose")
sns.histplot(x ="Blood_Pressure", data = df_d_knn, kde = True,ax=axes[0,1]).set(title = "Distribution of Blood_Pressure")
sns.histplot(x ="Skin_Thickness", data = df_d_knn, kde = True,ax=axes[0,2]).set(title = "Distribution of Skin_Thickness")
sns.histplot(x ="Insulin", data = df_d_knn, kde = True,ax=axes[1,0]).set(title = "Distribution of Insulin")
sns.histplot(x ="BMI", data = df_d_knn, kde = True,ax=axes[1,1]).set(title = "Distribution of BMI")
sns.histplot(x="Diabetes_Pedigree_Function",kde = True ,data = df_d_knn)

# %% [markdown]
# detecting outlier using IQR method. and replacing it with median value

# %% [markdown]
# ##**Outlier dealing for Blood pressure**

# %% [markdown]
# **using IQR Method to find oulier and then replacing it with median**

# %%
Q1=np.percentile(df_d_knn['Blood_Pressure'],25) #fiding Q1,Q2,Q3
Q2=np.percentile(df_d_knn['Blood_Pressure'],50)
Q3=np.percentile(df_d_knn['Blood_Pressure'],75)

# %%
IQR=Q3-Q1
low= Q1-1.5*IQR # taking limit as 1.5
high=Q3+1.5*IQR
print('low=',low)
print('high=',high)
# Out:
# low= 47.0
# high= 103.0

# %%
def rep(num): # Function to replace outlier with median
  if num>103 or num<47:
    return df_d_knn['Blood_Pressure'].median()
  else:
    return num

# %%
df_d_knn["Blood_Pressure_transform"]=df_d_knn['Blood_Pressure'].apply(rep) # calling function

# %% [markdown]
# ##**Outlier dealing for Skin Thickness**

# %%
Q1=np.percentile(df_d_knn['Skin_Thickness'],25) 
Q2=np.percentile(df_d_knn['Skin_Thickness'],50)
Q3=np.percentile(df_d_knn['Skin_Thickness'],75)

# %%
IQR=Q3-Q1
low= Q1-1.5*IQR
high=Q3+1.5*IQR
print('low=',low)
print('high=',high)
# Out:
# low= 14.5
# high= 50.5

# %%
def rep(num):
  if num>50.5 or num<14.5:
    return df_d_knn['Skin_Thickness'].median()
  else:
    return num

# %%
df_d_knn["Skin_Thickness_transform"]=df_d_knn['Skin_Thickness'].apply(rep)

# %% [markdown]
# ##**Outlier dealing for Insuline**

# %%
Q1=np.percentile(df_d_knn['Insulin'],25) 
Q2=np.percentile(df_d_knn['Insulin'],50)
Q3=np.percentile(df_d_knn['Insulin'],75)

# %%
IQR=Q3-Q1
low= Q1-1.5*IQR
high=Q3+1.5*IQR
print('low=',low)
print('high=',high)
# Out:
# low= 0.3771353128345254
# high= 365.26442322329467

# %%
def rep(num):
  if num>365.2 or num<0.37:
    return df_d_knn['Insulin'].median()
  else:
    return num

# %%
df_d_knn["Insulin_transform"]=df_d_knn['Insulin'].apply(rep)

# %% [markdown]
# ##**Outlier dealing for BMI**

# %%
Q1=np.percentile(df_d_knn['BMI'],25) 
Q2=np.percentile(df_d_knn['BMI'],50)
Q3=np.percentile(df_d_knn['BMI'],75)

# %%
IQR=Q3-Q1
low= Q1-1.5*IQR
high=Q3+1.5*IQR
print('low=',low)
print('high=',high)
# Out:
# low= 19.087499999999988
# high= 50.58750000000002

# %%
def rep(num):
  if num>50.58 or num< 19.087:
    return df_d_knn['BMI'].median()
  else:
    return num

# %%
df_d_knn["BMI_transform"]=df_d_knn['BMI'].apply(rep)

# %% [markdown]
# ##**Outlier dealing for Diabetes_Pedigree_Function**

# %%
Q1=np.percentile(df_d_knn['Diabetes_Pedigree_Function'],25) 
Q2=np.percentile(df_d_knn['Diabetes_Pedigree_Function'],50)
Q3=np.percentile(df_d_knn['Diabetes_Pedigree_Function'],75)

# %%
IQR=Q3-Q1
low= Q1-1.5*IQR
high=Q3+1.5*IQR
print('low=',low)
print('high=',high)
# Out:
# low= -0.4357499999999999
# high= 1.42625

# %%
def rep(num):
  if num>1.42625 or num<-0.43574999:
    return df_d_knn['Diabetes_Pedigree_Function'].median()
  else:
    return num

# %%
df_d_knn["Diabetes_Pedigree_Function_transform"]=df_d_knn['Diabetes_Pedigree_Function'].apply(rep)

# %%
df_d_knn['Age_transform'] = np.log(df_d_knn['Age'])

# %% [markdown]
# ##**Checking the distributioN after treating Outlier with median value**

# %%
fig,axes = plt.subplots(nrows = 3, ncols = 2, figsize = (20,10))  # Here Box plot is used for numerical data column to check outlier in the each column
sns.boxplot(x ="Blood_Pressure_transform", data = df_d_knn,ax=axes[0,0]).set(title = "Distribution of Blood_Pressure after tranform")
sns.boxplot(x ="Skin_Thickness_transform", data = df_d_knn, ax=axes[0,1]).set(title = "Distribution of Skin_Thickness after tranform")
sns.boxplot(x ="Insulin_transform", data = df_d_knn, ax=axes[1,0]).set(title = "Distribution of Insulin after tranform")
sns.boxplot(x ="BMI_transform", data = df_d_knn, ax=axes[1,1]).set(title = " BMI after tranform")
sns.boxplot(x ="Diabetes_Pedigree_Function_transform", data = df_d_knn, ax=axes[2,0]).set(title = " Diabetes_Pedigree after tranform")
# Out:
# [Text(0.5, 1.0, ' Diabetes_Pedigree after tranform')]

# %% [markdown]
# **Above box plot we can observe that , outlier are reduced**

# %%
fig,axes = plt.subplots(nrows = 3, ncols = 2, figsize = (18,10))  # Here Box plot is used for numerical data column to check outlier in the each column
sns.histplot(x ="Blood_Pressure_transform", data = df_d_knn,kde = True ,ax=axes[0,0]).set(title = "Distribution of Blood_Pressure after tranform")
sns.histplot(x ="Skin_Thickness_transform", data = df_d_knn,kde = True , ax=axes[0,1]).set(title = "Distribution of Skin_Thickness after tranform")
sns.histplot(x ="Insulin_transform", data = df_d_knn,kde = True , ax=axes[1,0]).set(title = "Distribution of Insulin after tranform")
sns.histplot(x ="BMI_transform", data = df_d_knn,kde = True , ax=axes[1,1]).set(title = " BMI after tranform")
sns.histplot(x ="Diabetes_Pedigree_Function_transform", data = df_d_knn,kde = True , ax=axes[2,0]).set(title = " Diabetes_Pedigree_Function after tranform")
# Out:
# [Text(0.5, 1.0, ' Diabetes_Pedigree_Function after tranform')]

# %% [markdown]
# **After tranforming outlier, the plot becom almost symetrical.**
#
# **But daibetic pedigree plot, still in right skewed. so we will go for log tranformation for the same**

# %%
df_d_knn['Diabetes_Pedigree_Function_log'] = np.log(df_d_knn['Diabetes_Pedigree_Function_transform']) #taking log

# %%
sns.histplot(x ="Diabetes_Pedigree_Function_log", data = df_d_knn, kde = True)

# %%
df_d_knn.describe(include = "all")
# Out:
#        Pregnancies     Glucose  Blood_Pressure  Skin_Thickness     Insulin  \
# count   268.000000  268.000000      268.000000      268.000000  268.000000
# mean      4.865672  142.320544       75.019231       32.821864  200.198736
# std       3.741239   29.489297       12.111558        8.862215  103.237022
# min       0.000000   78.000000       30.000000        7.000000   14.000000
# 25%       1.750000  119.000000       68.000000       28.000000  137.209868
# 50%       4.000000  140.000000       74.000000       32.000000  175.014291
# 75%       8.000000  167.000000       82.000000       37.000000  228.431690
# max      17.000000  199.000000      114.000000       99.000000  846.000000
#
#               BMI  Diabetes_Pedigree_Function         Age  Outcome  \
# count  268.000000                  268.000000  268.000000    268.0
# mean    35.410299                    0.550500   37.067164      1.0
# std      6.594224                    0.372354   10.968254      0.0
# ...

# %% [markdown]
# #**Exploring data set of non-diabetic people df_n**

# %%
df_n.shape # Size of non diabetic dataframe
# Out:
# (500, 9)

# %%
df_n.describe(include = "all")
# Out:
#        Pregnancies   Glucose  Blood_Pressure  Skin_Thickness     Insulin  \
# count   500.000000  500.0000      500.000000      500.000000  500.000000
# mean      3.298000  109.9800       68.184000       19.664000   68.792000
# std       3.017185   26.1412       18.063075       14.889947   98.865289
# min       0.000000    0.0000        0.000000        0.000000    0.000000
# 25%       1.000000   93.0000       62.000000        0.000000    0.000000
# 50%       2.000000  107.0000       70.000000       21.000000   39.000000
# 75%       5.000000  125.0000       78.000000       31.000000  105.000000
# max      13.000000  197.0000      122.000000       60.000000  744.000000
#
#               BMI  Diabetes_Pedigree_Function         Age  Outcome
# count  500.000000                  500.000000  500.000000    500.0
# mean    30.304200                    0.429734   31.190000      0.0
# std      7.689855                    0.299085   11.667655      0.0
# ...

# %% [markdown]
# **we can see that column Glucose, blood pressure, Skinthickness, Insulin BMI has minimun value = 0. which is practicaly not posible.**

# %%
df_n.duplicated().sum() #Counting dublicates in diabetic data set
# Out:
# 0

# %%
df_n.describe(include = "all")
# Out:
#        Pregnancies   Glucose  Blood_Pressure  Skin_Thickness     Insulin  \
# count   500.000000  500.0000      500.000000      500.000000  500.000000
# mean      3.298000  109.9800       68.184000       19.664000   68.792000
# std       3.017185   26.1412       18.063075       14.889947   98.865289
# min       0.000000    0.0000        0.000000        0.000000    0.000000
# 25%       1.000000   93.0000       62.000000        0.000000    0.000000
# 50%       2.000000  107.0000       70.000000       21.000000   39.000000
# 75%       5.000000  125.0000       78.000000       31.000000  105.000000
# max      13.000000  197.0000      122.000000       60.000000  744.000000
#
#               BMI  Diabetes_Pedigree_Function         Age  Outcome
# count  500.000000                  500.000000  500.000000    500.0
# mean    30.304200                    0.429734   31.190000      0.0
# std      7.689855                    0.299085   11.667655      0.0
# ...

# %% [markdown]
# **we can see that column Glucose, blood pressure, Skinthickness, Insulin BMI has minimun value = 0. which is practicaly not posible.**

# %% [markdown]
# ## **Checking for distributon of cloumn**

# %%
fig,axes = plt.subplots(nrows = 2, ncols = 3, figsize = (18,10))
sns.histplot(x ="Glucose", data = df_n, kde = True,ax=axes[0,0]).set(title = "Distribution of Glucose")
sns.histplot(x ="Blood_Pressure", data = df_n, kde = True,ax=axes[0,1]).set(title = "Distribution of Blood_Pressure")
sns.histplot(x ="Skin_Thickness", data = df_n, kde = True,ax=axes[0,2]).set(title = "Distribution of Skin_Thickness")
sns.histplot(x ="Insulin", data = df_n, kde = True,ax=axes[1,0]).set(title = "Distribution of Insulin")
sns.histplot(x ="BMI", data = df_n, kde = True,ax=axes[1,1]).set(title = "Distribution of BMI")
# Out:
# [Text(0.5, 1.0, 'Distribution of BMI')]

# %% [markdown]
# **ABOVE Figure shows the presence of zero in column, which is irrelevant.** **also we can see number of zeros on those column.**
# **most of zeros are found in column insulin. But insulin is a key factore** **of diebetic. so dropping zeros will effect the Analysis..**

# %%
df_n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 1 to 767
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Pregnancies                 500 non-null    int64
#  1   Glucose                     497 non-null    float64
#  2   Blood_Pressure              481 non-null    float64
#  3   Skin_Thickness              361 non-null    float64
#  4   Insulin                     264 non-null    float64
#  5   BMI                         491 non-null    float64
#  6   Diabetes_Pedigree_Function  500 non-null    float64
#  7   Age                         500 non-null    float64
#  8   Outcome                     500 non-null    int64
# dtypes: float64(7), int64(2)
# memory usage: 39.1 KB

# %%
df_n.isnull().sum() # COunting missing values for eacch count
# Out:
# Pregnancies                     0
# Glucose                         3
# Blood_Pressure                 19
# Skin_Thickness                139
# Insulin                       236
# BMI                             9
# Diabetes_Pedigree_Function      0
# Age                             0
# Outcome                         0
# dtype: int64

# %% [markdown]
# **we can see Triceps skin thickness and insulin has more missing values.**
#
# **But as per medicle science this two are key factore for deciding diabetis for a person, so drop this can effect the out come**
#
# **we will go for Replacing missing values**

# %%
import missingno as msno # Graphical representation of missing values
msno.bar(df_n)

# %%
sorted_matrix = df_n.sort_values(['Skin_Thickness','Insulin']) # matrix view of missing values
msno.matrix(sorted_matrix)
plt.show()

# %% [markdown]
# **Above Graph shows that, white line indicates that missing values**
# **We Can observe that the column skin thickness and Insulin has Relationin missing values.**

# %%
msno.heatmap(df_n)

# %% [markdown]
# **Above Graph Heat Mapp shows the co realation between columns**
#
# **We can observe that skin thickness and Insulin are highly positive co realated**

# %%
from sklearn.impute import SimpleImputer # since missing value is in categorical data, so replacing null values with mode
df_n_median = df_n.copy( deep = True)
median_imputer = SimpleImputer(strategy = "median")
df_n_median.iloc[:, :] = median_imputer.fit_transform(df_n_median)

# %%
df_n_median.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 1 to 767
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Pregnancies                 500 non-null    float64
#  1   Glucose                     500 non-null    float64
#  2   Blood_Pressure              500 non-null    float64
#  3   Skin_Thickness              500 non-null    float64
#  4   Insulin                     500 non-null    float64
#  5   BMI                         500 non-null    float64
#  6   Diabetes_Pedigree_Function  500 non-null    float64
#  7   Age                         500 non-null    float64
#  8   Outcome                     500 non-null    float64
# dtypes: float64(9)
# memory usage: 39.1 KB

# %%
#from fancyimpute import  # knn implimenation for missing values
from fancyimpute import KNN
knn_imputer = KNN()
df_n_knn = df_n.copy( deep = True)
df_n_knn.iloc[:, :] = knn_imputer.fit_transform(df_n_knn)
# Out:
# Imputing row 1/500 with 1 missing, elapsed time: 0.053
# Imputing row 101/500 with 0 missing, elapsed time: 0.057
# Imputing row 201/500 with 0 missing, elapsed time: 0.061
# Imputing row 301/500 with 0 missing, elapsed time: 0.065
# Imputing row 401/500 with 1 missing, elapsed time: 0.070

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2, figsize = (10,7))
nullity = df_n['Skin_Thickness'].isnull() + df_n['Insulin'].isnull()
imputations = {'Median Imputation' : df_n_median, 
               'KNN Imputation': df_n_knn}

for ax, df_key in zip(axes.flatten(), imputations):
  imputations[df_key].plot(x ='Skin_Thickness', y = 'Insulin', kind = 'scatter', alpha = 0.5, c= nullity, cmap = 'rainbow', ax = ax,colorbar = False, title = df_key)

# %% [markdown]
# **From Above Graph we can conclude that, for data fram df_n [Information about non - diabetic person] KNN Imputation wiil be the better approch.**
#
# **because in above plot we can observe that KNN imputation is almost similar to to the dataset, compared to median imputation**

# %% [markdown]
# ## **Checking for Outlier - non diabetic data set**

# %%
sns.boxplot(x ="Age", data = df_n_knn).set(title = "Distribution of BMI") # Checking outlier in age column
# Out:
# [Text(0.5, 1.0, 'Distribution of BMI')]

# %%
fig,axes = plt.subplots(nrows = 2, ncols = 3, figsize = (18,10))  # Here Box plot is used for numerical data column to check outlier in the each column
sns.boxplot(x ="Glucose", data = df_n_knn,ax=axes[0,0]).set(title = "Distribution of Glucose")
sns.boxplot(x ="Blood_Pressure", data = df_n_knn,ax=axes[0,1]).set(title = "Distribution of Blood_Pressure")
sns.boxplot(x ="Skin_Thickness", data = df_n_knn, ax=axes[0,2]).set(title = "Distribution of Skin_Thickness")
sns.boxplot(x ="Insulin", data = df_n_knn, ax=axes[1,0]).set(title = "Distribution of Insulin")
sns.boxplot(x ="BMI", data = df_n_knn, ax=axes[1,1]).set(title = "Distribution of BMI")
sns.boxplot(x="Diabetes_Pedigree_Function", data = df_n_knn)

# %%
fig,axes = plt.subplots(nrows = 2, ncols = 3, figsize = (18,10))
sns.histplot(x ="Glucose", data = df_n_knn, kde = True,ax=axes[0,0]).set(title = "Distribution of Glucose")
sns.histplot(x ="Blood_Pressure", data = df_n_knn, kde = True,ax=axes[0,1]).set(title = "Distribution of Blood_Pressure")
sns.histplot(x ="Skin_Thickness", data = df_n_knn, kde = True,ax=axes[0,2]).set(title = "Distribution of Skin_Thickness")
sns.histplot(x ="Insulin", data = df_n_knn, kde = True,ax=axes[1,0]).set(title = "Distribution of Insulin")
sns.histplot(x ="BMI", data = df_n_knn, kde = True,ax=axes[1,1]).set(title = "Distribution of BMI")
sns.histplot(x="Diabetes_Pedigree_Function",kde = True ,data = df_n_knn)

# %% [markdown]
# detecting outlier using IQR method. and replacing it with median value

# %% [markdown]
# ##**Outlier dealing for Glucose**

# %% [markdown]
# **using IQR Method to find oulier and then replacing it with median**

# %%
Q1=np.percentile(df_n_knn['Glucose'],25) 
Q2=np.percentile(df_n_knn['Glucose'],50)
Q3=np.percentile(df_n_knn['Glucose'],75)

# %%
IQR=Q3-Q1
low= Q1-1.5*IQR
high=Q3+1.5*IQR
print('low=',low)
print('high=',high)
# Out:
# low= 45.0
# high= 173.0

# %%
def rep(num):
  if num>173 or num<45:
    return df_n_knn['Glucose'].median()
  else:
    return num

# %%
df_n_knn["Glucose_transform"]=df_n_knn['Glucose'].apply(rep)

# %% [markdown]
# ##**Outlier dealing for Blood pressure**

# %%
Q1=np.percentile(df_n_knn['Blood_Pressure'],25) 
Q2=np.percentile(df_n_knn['Blood_Pressure'],50)
Q3=np.percentile(df_n_knn['Blood_Pressure'],75)

# %%
IQR=Q3-Q1
low= Q1-1.5*IQR
high=Q3+1.5*IQR
print('low=',low)
print('high=',high)
# Out:
# low= 38.0
# high= 102.0

# %%
def rep(num):
  if num>102 or num<38:
    return df_n_knn['Blood_Pressure'].median()
  else:
    return num

# %%
df_n_knn["Blood_Pressure_transform"]=df_n_knn['Blood_Pressure'].apply(rep)

# %% [markdown]
# ##**Outlier dealing for Skin Thickness**

# %%
Q1=np.percentile(df_n_knn['Skin_Thickness'],25) 
Q2=np.percentile(df_n_knn['Skin_Thickness'],50)
Q3=np.percentile(df_n_knn['Skin_Thickness'],75)

# %%
IQR=Q3-Q1
low= Q1-1.5*IQR
high=Q3+1.5*IQR
print('low=',low)
print('high=',high)
# Out:
# low= 1.8117222637938326
# high= 50.31379622701028

# %%
def rep(num):
  if num>50.31 or num<1.8117:
    return df_n_knn['Skin_Thickness'].median()
  else:
    return num

# %%
df_n_knn["Skin_Thickness_transform"]=df_n_knn['Skin_Thickness'].apply(rep)

# %% [markdown]
# ##**Outlier dealing for Insuline**

# %%
Q1=np.percentile(df_n_knn['Insulin'],25) 
Q2=np.percentile(df_n_knn['Insulin'],50)
Q3=np.percentile(df_n_knn['Insulin'],75)

# %%
IQR=Q3-Q1
low= Q1-1.5*IQR
high=Q3+1.5*IQR
print('low=',low)
print('high=',high)
# Out:
# low= -56.55421715221934
# high= 280.9236952536989

# %%
def rep(num):
  if num>280.9236 or num<-56.554:
    return df_n_knn['Insulin'].median()
  else:
    return num

# %%
df_n_knn["Insulin_transform"]=df_n_knn['Insulin'].apply(rep)

# %% [markdown]
# ##**Outlier dealing for BMI**

# %%
Q1=np.percentile(df_n_knn['BMI'],25) 
Q2=np.percentile(df_n_knn['BMI'],50)
Q3=np.percentile(df_n_knn['BMI'],75)

# %%
IQR=Q3-Q1
low= Q1-1.5*IQR
high=Q3+1.5*IQR
print('low=',low)
print('high=',high)
# Out:
# low= 11.425000000000004
# high= 49.62499999999999

# %%
def rep(num):
  if num>49.624 or num<11.4250:
    return df_n_knn['BMI'].median()
  else:
    return num

# %%
df_n_knn["BMI_transform"]=df_n_knn['BMI'].apply(rep)

# %% [markdown]
# ##**Outlier dealing for Diabetes_Pedigree_Function**

# %%
Q1=np.percentile(df_n_knn['Diabetes_Pedigree_Function'],25) 
Q2=np.percentile(df_n_knn['Diabetes_Pedigree_Function'],50)
Q3=np.percentile(df_n_knn['Diabetes_Pedigree_Function'],75)

# %%
IQR=Q3-Q1
low= Q1-1.5*IQR
high=Q3+1.5*IQR
print('low=',low)
print('high=',high)
# Out:
# low= -0.26824999999999993
# high= 1.05975

# %%
def rep(num):
  if num>1.05975 or num<-0.26824:
    return df_n_knn['Diabetes_Pedigree_Function'].median()
  else:
    return num

# %%
df_n_knn["Diabetes_Pedigree_Function_transform"]=df_n_knn['Diabetes_Pedigree_Function'].apply(rep)

# %% [markdown]
# ##**Outlier dealing for Age**

# %%
df_n_knn['Age_transform'] = np.log(df_n_knn['Age'])

# %% [markdown]
# ##**Checking the distributioN after treating Outlier with median value**

# %%
fig,axes = plt.subplots(nrows = 3, ncols = 2, figsize = (18,10))  # Here Box plot is used for numerical data column to check outlier in the each column
sns.boxplot(x ="Blood_Pressure_transform", data = df_n_knn,ax=axes[0,0]).set(title = "Distribution of Blood_Pressure after tranform")
sns.boxplot(x ="Skin_Thickness_transform", data = df_n_knn, ax=axes[0,1]).set(title = "Distribution of Skin_Thickness after tranform")
sns.boxplot(x ="Insulin_transform", data = df_n_knn, ax=axes[1,0]).set(title = "Distribution of Insulin after tranform")
sns.boxplot(x ="BMI_transform", data = df_n_knn, ax=axes[1,1]).set(title = " BMI after tranform")
sns.boxplot(x ="Diabetes_Pedigree_Function_transform", data = df_n_knn, ax=axes[2,0]).set(title = " Diabetes_Pedigree after tranform")
sns.boxplot(x ="Glucose_transform", data = df_n_knn, ax=axes[2,1]).set(title = " Glucose after tranform")
# Out:
# [Text(0.5, 1.0, ' Glucose after tranform')]

# %%
sns.boxplot(x= "Age_transform", data = df_n_knn);

# %% [markdown]
# **Above box plot we can observe that , outlier are reduced**

# %%
fig,axes = plt.subplots(nrows = 3, ncols = 2, figsize = (18,10))  # Here Box plot is used for numerical data column to check outlier in the each column
sns.histplot(x ="Blood_Pressure_transform", data = df_n_knn,kde = True ,ax=axes[0,0]).set(title = "Distribution of Blood_Pressure after tranform")
sns.histplot(x ="Skin_Thickness_transform", data = df_n_knn,kde = True , ax=axes[0,1]).set(title = "Distribution of Skin_Thickness after tranform")
sns.histplot(x ="Insulin_transform", data = df_n_knn,kde = True , ax=axes[1,0]).set(title = "Distribution of Insulin after tranform")
sns.histplot(x ="BMI_transform", data = df_n_knn,kde = True , ax=axes[1,1]).set(title = " BMI after tranform")
sns.histplot(x ="Diabetes_Pedigree_Function_transform", data = df_n_knn,kde = True , ax=axes[2,0]).set(title = " Diabetes_Pedigree_Function after tranform")
sns.histplot(x ="Glucose_transform", kde = True , data = df_n_knn, ax=axes[2,1]).set(title = " Glucose after tranform")
# Out:
# [Text(0.5, 1.0, ' Glucose after tranform')]

# %% [markdown]
# **After tranforming outlier, the plot becom almost symetrical.**
#
# **But daibetic pedigree plot, still in right skewed. so we will go for log tranformation for the same**

# %%
df_n_knn['Diabetes_Pedigree_Function_log'] = np.log(df_n_knn['Diabetes_Pedigree_Function_transform'])

# %%
sns.histplot(x ="Diabetes_Pedigree_Function_log", data = df_n_knn, kde = True)

# %%
df_n_knn.describe(include = "all")
# Out:
#        Pregnancies     Glucose  Blood_Pressure  Skin_Thickness     Insulin  \
# count   500.000000  500.000000      500.000000      500.000000  500.000000
# mean      3.298000  110.487251       70.813504       27.035384  125.144449
# std       3.017185   24.785331       12.048527        9.122317   84.325099
# min       0.000000   44.000000       24.000000        7.000000   15.000000
# 25%       1.000000   93.000000       62.000000       20.000000   70.000000
# 50%       2.000000  107.000000       70.000000       27.000000  106.491564
# 75%       5.000000  125.000000       78.000000       32.125518  154.369478
# max      13.000000  197.000000      122.000000       60.000000  744.000000
#
#               BMI  Diabetes_Pedigree_Function         Age  Outcome  \
# count  500.000000                  500.000000  500.000000    500.0
# mean    30.834525                    0.429734   31.190000      0.0
# std      6.508491                    0.299085   11.667655      0.0
# ...

# %% [markdown]
# #**ANALYZING THE BIOLOGICAL PARAMETER OF DIABETIC AND NON-DIABETIC PATIENTS**

# %% [markdown]
# **Combining the cleaned data of diabetic and non diabetic patients**

# %%
df_d_knn.shape # shape of cleanend diabetic patients data
# Out:
# (268, 16)

# %%
df_d_knn["Glucose_transform"] = df_d_knn["Glucose"]
df_d_knn['Age_transform'] = df_d_knn["Age"]

# %%
df_d_knn.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'Blood_Pressure', 'Skin_Thickness', 'Insulin',
#        'BMI', 'Diabetes_Pedigree_Function', 'Age', 'Outcome',
#        'Blood_Pressure_transform', 'Skin_Thickness_transform',
#        'Insulin_transform', 'BMI_transform',
#        'Diabetes_Pedigree_Function_transform', 'Age_transform',
#        'Diabetes_Pedigree_Function_log', 'Glucose_transform'],
#       dtype='object')

# %%
df_n_knn.shape # shape of cleaned non diabetic patients data
# Out:
# (500, 17)

# %%
df_n_knn.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'Blood_Pressure', 'Skin_Thickness', 'Insulin',
#        'BMI', 'Diabetes_Pedigree_Function', 'Age', 'Outcome',
#        'Glucose_transform', 'Blood_Pressure_transform',
#        'Skin_Thickness_transform', 'Insulin_transform', 'BMI_transform',
#        'Diabetes_Pedigree_Function_transform', 'Age_transform',
#        'Diabetes_Pedigree_Function_log'],
#       dtype='object')

# %%
frames = [df_d_knn, df_n_knn]
  
df_final = pd.concat(frames) # Final combined dataframe
display(df_final)

# %%
df_final = df_final.astype({"Outcome" : str})

# %%
df_final.loc[df["Outcome"] == 0.0, "Outcome"] = "non-diabetic" # changing out come to string

# %%
df_final.loc[df["Outcome"] == 1.0, "Outcome"] = "diabetic"

# %%
df_final.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'Blood_Pressure', 'Skin_Thickness', 'Insulin',
#        'BMI', 'Diabetes_Pedigree_Function', 'Age', 'Outcome',
#        'Blood_Pressure_transform', 'Insulin_transform', 'BMI_transform',
#        'Diabetes_Pedigree_Function_transform', 'Skin_Thickness_transform',
#        'Diabetes_Pedigree_Function_log', 'Glucose_transform', 'Age_transform'],
#       dtype='object')

# %% [markdown]
# ##**Comparsion of Glucose Level for diabetic and non-diabetic patient**

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 3, figsize = (20,7))  # Comparing Glucose level of diabetic and aged people
sns.boxplot(y ="Glucose",color = "red", data = df_d_knn ,ax=axes[0]).set(title = "Glucose level of diabetic patients" , ylabel = "Glucose Level")
sns.boxplot(y ="Glucose_transform",color = "green", data = df_n_knn , ax=axes[1]).set(title = "Glucose level of diabetic non-patients", ylabel = "Glucose Level")
sns.boxplot(y ="Glucose_transform", x = "Outcome", data = df_final , ax=axes[2]).set(title = "comparison Glucose level for diabetic and non-diabetic" , ylabel = "Glucose Level")
# Out:
# [Text(0, 0.5, 'Glucose Level'),
#  Text(0.5, 1.0, 'comparison Glucose level for diabetic and non-diabetic')]

# %% [markdown]
# **Above figure shows the comparison glucose level for diabetic and non- diabetic patient following points can e observed in the graph**
#
#
# *   **Median value of Glucose level of diabetic patient is around 140**
# *   **Median value of Glucose level of non-diabetic patient is around 110**
# *   **Glucose concentration in blood of diabetic patient is more than non diabetic patient**
# *  **Glucose level of diabetic patients is inbetween 120 to 170**
# *  **Glucose level of non diabetic patient is inbetween 90 to 125**

# %% [markdown]
# ##**Comparsion of Blood_Pressure for diabetic and non-diabetic patient**

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 3, figsize = (20,7))  # Comparing Glucose level of diabetic and aged people
sns.boxplot(y ="Blood_Pressure_transform",color = "red", data = df_d_knn ,ax=axes[0]).set(title = "Blood Pressure of diabetic patients" , ylabel = "Blood Pressure")
sns.boxplot(y ="Blood_Pressure_transform",color = "green", data = df_n_knn , ax=axes[1]).set(title = "Blood Pressure of diabetic non-patients", ylabel = "Blood Pressure")
sns.boxplot(y ="Blood_Pressure_transform", x = "Outcome", data = df_final , ax=axes[2]).set(title = "comparison Blood Pressure for diabetic and non-diabetic" , ylabel = "Blood Pressure")
# Out:
# [Text(0, 0.5, 'Blood Pressure'),
#  Text(0.5, 1.0, 'comparison Blood Pressure for diabetic and non-diabetic')]

# %% [markdown]
# **Above figure shows the comparison Bood Pressure for diabetic and non- diabetic patient following points can e observed in the graph**
#
# *  **Blood Pressure for Diabetic patient is more than that of non diabetic patient**
#
# *  **Median value of Blood Pressure of diabetic patient is above 70mm Hg**
#
# *  **Median value of Blood Pressure of non-diabetic patient is below 70mm Hg**

# %% [markdown]
# ##**Comparsion of Triceps skin fold thickness for diabetic and non-diabetic patient**

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 3, figsize = (20,7))  # Comparing Glucose level of diabetic and aged people
sns.boxplot(y ="Skin_Thickness_transform",color = "red", data = df_d_knn ,ax=axes[0]).set(title = "Skin_Thickness of diabetic patients" , ylabel = "Skin_Thickness mm")
sns.boxplot(y ="Skin_Thickness_transform",color = "green", data = df_n_knn , ax=axes[1]).set(title = "Skin_Thickness of diabetic non-patients", ylabel = "Skin_Thickness mm")
sns.boxplot(y ="Skin_Thickness_transform", x = "Outcome", data = df_final , ax=axes[2]).set(title = "comparison Skin_Thickness for diabetic and non-diabetic" , ylabel = "Skin_Thickness mm")
# Out:
# [Text(0, 0.5, 'Skin_Thickness mm'),
#  Text(0.5, 1.0, 'comparison Skin_Thickness for diabetic and non-diabetic')]

# %% [markdown]
# **Above figure shows the comparison Skin_Thickness for diabetic and non- diabetic patient following points can e observed in the graph**
#
# *  **Triceps Skin Thickness for diabetic patient is more than that of non diabetic patient**
#
# *  **Median value of Skin Thickness of diabetic patient is above 30mm**
#
# *  **Median value of Skin Thickness of non-diabetic patient is below 30mm**
#
# * **Skin thickness for diabetic patient is concentrated more towards thicker side**

# %% [markdown]
# ##**Comparsion of  Insulin for diabetic and non-diabetic patient**

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 3, figsize = (20,7))  # Comparing Glucose level of diabetic and aged people
sns.boxplot(y ="Insulin_transform",color = "red", data = df_d_knn ,ax=axes[0]).set(title = "Insulin level of diabetic patients" , ylabel = "Insulin mu U/ml")
sns.boxplot(y ="Insulin_transform",color = "green", data = df_n_knn , ax=axes[1]).set(title = "Insulin level of diabetic non-patients", ylabel = "Insulin mu U/ml")
sns.boxplot(y ="Insulin_transform", x = "Outcome", data = df_final , ax=axes[2]).set(title = "Comparison Insulin level for diabetic and non-diabetic" , ylabel = "Insulin mu U/ml")
# Out:
# [Text(0, 0.5, 'Insulin mu U/ml'),
#  Text(0.5, 1.0, 'Comparison Insulin level for diabetic and non-diabetic')]

# %% [markdown]
# **Above figure shows the comparison Insulin for diabetic and non- diabetic patient following points can e observed in the graph**
#
# *  **Insulin for diabetic patient is more than that of non diabetic patient**
#
# *  **Median value of Insulin of diabetic patient is around 170 mu U/ml**
#
# *  **Median value of Insulin of non-diabetic patient is around 100 mu U/ml**
#
# * **Insulin level can be good measure to find Diabetes**

# %% [markdown]
# ##**Comparsion of  BMI for diabetic and non-diabetic patient**

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 3, figsize = (20,7))  # Comparing Glucose level of diabetic and aged people
sns.boxplot(y ="BMI_transform",color = "red", data = df_d_knn ,ax=axes[0]).set(title = "BMI of diabetic patients" , ylabel = "BMI")
sns.boxplot(y ="BMI_transform",color = "green", data = df_n_knn , ax=axes[1]).set(title = "BMI of diabetic non-patients", ylabel = "BMI")
sns.boxplot(y ="BMI_transform", x = "Outcome", data = df_final , ax=axes[2]).set(title = "Comparison of BMI for diabetic and non-diabetic" , ylabel = "BMI")
# Out:
# [Text(0, 0.5, 'BMI'),
#  Text(0.5, 1.0, 'Comparison of BMI for diabetic and non-diabetic')]

# %% [markdown]
# **Above figure shows the comparison BMI for diabetic and non- diabetic patient following points can be observed in the graph**
#
# *  **Body Mass Index for diabetic patient is more than that of non diabetic patient**
#
# *  **Diabetic patient has more body weight compared to their body hight**
#
# *  **Diabetic Patient has High body fat compared to non diabetic person**

# %% [markdown]
# ##**Comparsion of  Diabetes Pedigree Function for diabetic and non-diabetic patient**

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 3, figsize = (20,7))  # Comparing Glucose level of diabetic and aged people
sns.boxplot(y ="Diabetes_Pedigree_Function_log",color = "red", data = df_d_knn ,ax=axes[0]).set(title = "Diabetes Pedigree Function of diabetic patients" , ylabel = "Diabetes Pedigree Function")
sns.boxplot(y ="Diabetes_Pedigree_Function_log",color = "green", data = df_n_knn , ax=axes[1]).set(title = "Diabetes Pedigree Function of diabetic non-patients", ylabel = "Diabetes Pedigree Function")
sns.boxplot(y ="Diabetes_Pedigree_Function_log", x = "Outcome", data = df_final , ax=axes[2]).set(title = "Comparison of Diabetes Pedigree Function for diabetic and non-diabetic" , ylabel = "Diabetes Pedigree Function")
# Out:
# [Text(0, 0.5, 'Diabetes Pedigree Function'),
#  Text(0.5, 1.0, 'Comparison of Diabetes Pedigree Function for diabetic and non-diabetic')]

# %% [markdown]
# **Above figure shows the comparison Diabetes Pedigree Function for diabetic and non- diabetic patient following points can be observed in the graph**
#
# *  **Diabetes Pedigree Function has significent effect on diabetes**
#
# *  **if family member has then diabetes then there is a high chance of next generation to have diabetes**

# %% [markdown]
# ##**Comparsion of  Age for diabetic and non-diabetic patient**

# %%
sns.boxplot(x= "Age", data = df_d_knn)

# %% [markdown]
# **Above figure shows the comparison Age for diabetic**
#
# *  **Age between 28 to 45 are high chance of getting diabetes**
#
# *  **Median age of diabetes patient is 35. that mean patients aged 35 are highly suffering from diabetes**

# %%
fig = plt.figure(figsize = (10,7))
sns.scatterplot(x= "Age", y= "Glucose_transform", hue = "Outcome", data = df_final).set(title = "Relation between glucose leve and Age and Diabetic" , ylabel = "Glucose level")
# Out:
# [Text(0, 0.5, 'Glucose level'),
#  Text(0.5, 1.0, 'Relation between glucose leve and Age and Diabetic')]

# %% [markdown]
# **Above figure shows the relation between Glucose level age on diabetes**
#
# *  **We can observe that age below 30 has lower level of Glucose, also they are non diabetic**
#
# *  **if Glucose level goes above 160 then , even 20 year old person will become diabetic**
#
# *  **As age goes above 30, even at below 160 glucose level, patient will be effected with diabetes**

# %%
sns.scatterplot(x= "Insulin_transform", y="Glucose_transform", hue = "Outcome" , data = df_final).set(title = "Relation between glucose leve and Insulin and Diabetic" , ylabel = "Glucose level", xlabel = "Insulin")
# Out:
# [Text(0, 0.5, 'Glucose level'),
#  Text(0.5, 0, 'Insulin'),
#  Text(0.5, 1.0, 'Relation between glucose leve and Insulin and Diabetic')]

# %% [markdown]
# **Above Graph shows the relaton between Insulin, Glucose level, and diabetic status**
#
# *  **Insulin and glucose has linear relation**
#
# *  **we can Observe that, insulin level below 150 and Glucose level below 120 has very low posibility of having diabetes**
#
# *  **We can Observe that, Insulin and Glucose are the key column to identify the Diabetes**

# %%
sns.scatterplot(x= "BMI_transform", y="Skin_Thickness_transform", hue = "Outcome" , data = df_final).set(title = "Relation between BMI leve and Skin Thickness and Diabetic" , ylabel = "Skin Thickness", xlabel = "BMI")
# Out:
# [Text(0, 0.5, 'Skin Thickness'),
#  Text(0.5, 0, 'BMI'),
#  Text(0.5, 1.0, 'Relation between BMI leve and Skin Thickness and Diabetic')]

# %% [markdown]
# **Above figure shows the relation between Triceps skin thickness and BMI and diabetic status**
#
# * **non diabetic people has lower BMI and skinthickness**

# %%
sns.scatterplot(x= "Pregnancies", y="Age", hue = "Outcome" , data = df_final).set(title = "Relation between BMI leve and Skin Thickness and Diabetic" , ylabel = "Age", xlabel = "Pregnancies")
# Out:
# [Text(0, 0.5, 'Age'),
#  Text(0.5, 0, 'Pregnancies'),
#  Text(0.5, 1.0, 'Relation between BMI leve and Skin Thickness and Diabetic')]

# %% [markdown]
# **Above graph shows the relation between age and pregnancies on diabetes**
# *  **We can see that, women who had pregnancies before 30 age are having less posibility of having diabetes**

# %% [markdown]
# #**Conclusion**

# %% [markdown]
# **From above above analysis, we an conclude that there is biological parameter like  Pregnancies: Number of times pregnant,
# Glucose, Blood Pressure,Skin Thickness, Insulin, BMI,Diabetes Pedigree Function,Age, has significant effect on daibetes.**
#
# **diabetes occur when glucose level, and insulin level in blood increases**
#
# **Measurment Glucose and Isulin level in blood can be used to find diabetes**
#
#
# **Diabetes may even occure as erly as age 20s, if glucose level and BMI is not maintained**
